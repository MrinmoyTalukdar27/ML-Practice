# %% [markdown]
# #### Write a Python program to implement Linear Regression with Multiple Variables.

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
X = np.array([
    [1000, 2],
    [1500, 3],
    [2000, 4],
    [2500, 4],
    [3000, 5]
])

y = np.array([200000, 300000, 400000, 500000, 600000])

# %%
model = LinearRegression()
model.fit(X, y)

prediction = model.predict([[2200, 4]])

print("Predicted Price:", prediction[0])
# Out:
# Predicted Price: 440000.0
