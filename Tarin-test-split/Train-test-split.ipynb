# %% [markdown]
# ### We lode the pandas and the n we lode the datset

# %%
import pandas as pd

# %%
df=pd.read_csv("House.csv")

# %%
df.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000.0         3       1.50         1340      7912     1.5           0
# 1  2384000.0         5       2.50         3650      9050     2.0           0
# 2   342000.0         3       2.00         1930     11947     1.0           0
# 3   420000.0         3       2.25         2000      8030     1.0           0
# 4   550000.0         4       2.50         1940     10500     1.0           0
#
#    view  condition  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3        1340              0      1955          2005
# 1     4          5        3370            280      1921             0
# 2     0          4        1930              0      1966             0
# 3     0          4        1000           1000      1963             0
# 4     0          4        1140            800      1976          1992
#
#                      street       city  statezip country
# ...

# %%
x=df.drop('price',axis=1)
y=df['price']
# Here in x we will drop the output column which is price and other then that column
# we will store the other column which are the input column in x
# when we again call the datafream 
# Then we will pass the price column in y variable because we are not droping the price permantly in x
# so we seperated our input and output column in x and y simultaneously

# %%
from sklearn.model_selection import train_test_split
# Her we are calling a class from sklearn name model_selection where we have a function called tarin_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.20,random_state=42)

# Here we calling the train_test_split function and we are storing the split result in x_train,x_test,Y_train,y_test
# the function automatically split the data

# %%
x_test.head(5)
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 3683         3       2.50         1460      1613     2.0           0     0
# 4411         5       2.25         2000      7900     1.0           0     0
# 2584         3       3.25         2940      5432     3.0           0     3
# 69           3       2.50         2200      7350     1.0           0     0
# 1844         3       2.50         1720      8755     1.0           0     0
#
#       condition  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 3683          3        1180            280      2007             0
# 4411          4        1300            700      1986             0
# 2584          4        2440            500      1978          2000
# 69            5        1570            630      1988             0
# 1844          3        1000            720      1983          2009
#
#                   street         city  statezip country
# ...

# %%
x_test.head(5)
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 3683         3       2.50         1460      1613     2.0           0     0
# 4411         5       2.25         2000      7900     1.0           0     0
# 2584         3       3.25         2940      5432     3.0           0     3
# 69           3       2.50         2200      7350     1.0           0     0
# 1844         3       2.50         1720      8755     1.0           0     0
#
#       condition  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 3683          3        1180            280      2007             0
# 4411          4        1300            700      1986             0
# 2584          4        2440            500      1978          2000
# 69            5        1570            630      1988             0
# 1844          3        1000            720      1983          2009
#
#                   street         city  statezip country
# ...

# %%
y_train.head(5)
# Out:
# 1828    400000.0
# 1573    400000.0
# 319     258000.0
# 653     565000.0
# 2137    550000.0
# Name: price, dtype: float64

# %%
y_test.head(5)
# Out:
# 3683     544000.0
# 4411          0.0
# 2584    1712500.0
# 69       365000.0
# 1844     275000.0
# Name: price, dtype: float64
