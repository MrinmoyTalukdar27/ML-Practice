# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

# %%
df = pd.read_csv('titanic_updated.csv')
# here we create missing values in the dataset just to practice so this is not the real dataset

# %%
df.head()
# Out:
#     Age     Fare  Family  Survived
# 0  22.0   7.2500       1         0
# 1  38.0  71.2833       1         1
# 2  26.0   7.9250       0         1
# 3  35.0  53.1000       1         1
# 4  35.0   8.0500       0         0

# %%
df.isnull().mean()
# we can see we have missing values at Age and Fare
# Out:
# Age         0.198653
# Fare        0.050505
# Family      0.000000
# Survived    0.000000
# dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(df.drop('Survived',axis=1),df['Survived'],test_size=0.20,random_state=2)

# %%
x_train.head()
# Out:
#       Age     Fare  Family
# 30   40.0  27.7208       0
# 10    4.0  16.7000       2
# 873  47.0   9.0000       0
# 182   9.0  31.3875       6
# 876  20.0   9.8458       0

# %%
y_train.head()
# Out:
# 30     0
# 10     1
# 873    0
# 182    0
# 876    0
# Name: Survived, dtype: int64

# %%
# Now we will gonna do mean and median imputation so we need the mean,median of Age and Fare
mediam_age=x_train['Age'].median()
mean_age=x_train['Age'].mean()

mediam_fare=x_train['Fare'].median()
mean_fare=x_train["Fare"]

# %%
# Now we will use pandas fillna function to fill the missing valus
x_train['Age_median']=x_train['Age'].fillna(mediam_age)
x_train['Age_mean']=x_train['Age'].fillna(mean_age)

x_train['Fare_median']=x_train['Fare'].fillna(mediam_fare)
x_train['Faare_mean']=x_train['Fare'].fillna(mean_fare)

# %%
x_train.sample(5)
# Out:
#       Age     Fare  Family  Age_median  Age_mean  Fare_median  Faare_mean
# 555  62.0  26.5500       0        62.0      62.0      26.5500     26.5500
# 693  25.0   7.2250       0        25.0      25.0       7.2250      7.2250
# 161  40.0  15.7500       0        40.0      40.0      15.7500     15.7500
# 11   58.0  26.5500       0        58.0      58.0      26.5500     26.5500
# 39   14.0  11.2417       1        14.0      14.0      11.2417     11.2417
