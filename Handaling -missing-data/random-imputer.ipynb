# %%
#libary we need
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# sklearn function
from sklearn .model_selection import train_test_split

# %%
df=pd.read_csv('modified-titanic.csv',usecols=['Age','Fare','Survived'])

# %%
df.head(5)
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
#now we will check the missing values present in our data in persentage
df.isnull().mean()*100
# Out:
# Survived     0.00000
# Age         19.86532
# Fare         0.00000
# dtype: float64

# %%
# now herer we wre creating our x and y
x=df.drop(columns=['Survived'])
y=df['Survived']

# %%
#Now we we will do the train test split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
x_train['Age_impu'] = x_train['Age'] # here we are creating a temp column to see the changes befor and after the missing the imputation.
x_test['Age_impu'] = x_test['Age']

x_train['Age_impu'][x_train['Age_impu'].isnull()] = x_train['Age'].dropna().sample(x_train['Age_impu'].isnull().sum()).values
x_test['Age_impu'][x_test['Age_impu'].isnull()] = x_test['Age'].dropna().sample(x_test['Age_impu'].isnull().sum()).values
# Out:
# C:\Users\mrinm\AppData\Local\Temp\ipykernel_1448\3233347934.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
x_train
# Out:
#       Age      Fare  Age_impu
# 30   40.0   27.7208      40.0
# 10    4.0   16.7000       4.0
# 873  47.0    9.0000      47.0
# 182   9.0   31.3875       9.0
# 876  20.0    9.8458      20.0
# ..    ...       ...       ...
# 534  30.0    8.6625      30.0
# 584   NaN    8.7125      21.0
# 493  71.0   49.5042      71.0
# 527   NaN  221.7792      27.0
# 168   NaN   25.9250      34.0
#
# [712 rows x 3 columns]

# %%
# now we see the data distrubution befor and after the imputation
sns.displot(x_train['Age'],label='Before imputation',color='green')
sns.displot(x_train['Age_impu'],label='After the imputation',color='orange')
plt.legend()
plt.show()

# %%
# Now for catagorical data
data=pd.read_csv('house-train.csv',usecols=['GarageQual','FireplaceQu','SalePrice'])

# %%
df.head(5)
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
df.isnull().mean()
# Out:
# Survived    0.000000
# Age         0.198653
# Fare        0.000000
# dtype: float64

# %%
x =data
y =data['SalePrice']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
print(x_train.columns)
print(x_test.columns)
# Out:
# Index(['FireplaceQu', 'GarageQual', 'SalePrice'], dtype='object')
# Index(['FireplaceQu', 'GarageQual', 'SalePrice'], dtype='object')

# %%
# create temp columns
x_train['GarageQual_impu'] = x_train['GarageQual']
x_test['GarageQual_impu'] = x_test['GarageQual']

# fill missing values
x_train['GarageQual_impu'][x_train['GarageQual_impu'].isnull()] = x_train['GarageQual'].dropna().sample(x_train['GarageQual_impu'].isnull().sum(), replace=True).values

x_test['GarageQual_impu'][x_test['GarageQual_impu'].isnull()] = x_test['GarageQual'].dropna().sample(x_test['GarageQual_impu'].isnull().sum(), replace=True).values

# %%
# create temp columns
x_train['FireplaceQu_impu'] = x_train['FireplaceQu']
x_test['FireplaceQu_impu'] = x_test['FireplaceQu']

# fill missing values
x_train['FireplaceQu_impu'][x_train['FireplaceQu_impu'].isnull()] = x_train['FireplaceQu'].dropna().sample(x_train['FireplaceQu_impu'].isnull().sum(), replace=True).values

x_test['FireplaceQu_impu'][x_test['FireplaceQu_impu'].isnull()] = x_test['FireplaceQu'].dropna().sample(x_test['FireplaceQu_impu'].isnull().sum(), replace=True).values
# Out:
# C:\Users\mrinm\AppData\Local\Temp\ipykernel_1448\3599734479.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...
